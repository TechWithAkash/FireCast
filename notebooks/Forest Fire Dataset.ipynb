# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel('Algerian_forest_fires_dataset_UPDATE (1).xlsx',header=1)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4   RH           245 non-null    object
#  5   Ws           245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain  \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN  NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN  NaN
# 168                             14     7  2012          37   37   18  0.2
#
#      FFMC   DMC      DC   ISI   BUI   FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 123   NaN   NaN     NaN   NaN   NaN   NaN     NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire     NaN

# %%
df1.loc[:122,'Region'] = 0
df1.loc[122:,'Region'] = 1
df1= df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %%
df.head(2)
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  FWI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4  7.6  1.3  3.4  0.5
# 1    2      6  2012           29  61  13   1.3  64.4  4.1  7.6  1.0  3.9  0.4
#
#     Classes  Region
# 0  not fire       0
# 1  not fire       0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
# Removing the Missing values
df = df.dropna().reset_index(drop=True)

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 122    1      6  2012           32  71  12   0.7  57.1  2.5  8.2  0.6  2.8
#
#      FWI   Classes  Region
# 122  0.2  not fire       1

# %%
# Droping 122nd Cloumn
df = df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC   DC  ISI  BUI  \
# 122    2      6  2012           30  73  13   4.0  55.7  2.7  7.8  0.6  2.9
#
#      FWI   Classes  Region
# 122  0.2  not fire       1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
#fixes the blank Spaces in Column names

df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int32
#  1   month        242 non-null    int32
#  2   year         242 non-null    int32
#  3   Temperature  242 non-null    int32
#  4   RH           242 non-null    int32
#  5   Ws           242 non-null    int32
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.9+ KB

# %%
# Change the required columns into integars
df[['day','month','year','Temperature','RH','Ws']] = df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int32
#  1   month        242 non-null    int32
#  2   year         242 non-null    int32
#  3   Temperature  242 non-null    int32
#  4   RH           242 non-null    int32
#  5   Ws           242 non-null    int32
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.9+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
objects = [features for features in df.columns if df[features].dtype == "O"]

# %%
objects
# Out:
# ['Classes']

# %%
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int32
#  1   month        242 non-null    int32
#  2   year         242 non-null    int32
#  3   Temperature  242 non-null    int32
#  4   RH           242 non-null    int32
#  5   Ws           242 non-null    int32
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  FWI          242 non-null    float64
#  13  Classes      242 non-null    object
#  14  Region       242 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 21.9+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  242.000000  242.000000   242.0   242.000000  242.000000  242.000000
# mean    15.822314    7.508264  2012.0    32.152893   62.004132   15.508264
# std      8.809501    1.112888     0.0     3.635545   14.847635    2.808171
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.250000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.750000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  242.000000  242.000000  242.000000  242.000000  242.000000  242.000000
# mean     0.763223   77.928099   14.730992   49.601240    4.759504   16.747934
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  Region
# 0  0.5  not fire       0
# 1  0.4  not fire       0
# 2  0.1  not fire       0
# 3  0.0  not fire       0
# 4  0.5  not fire       0

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
# Let Saved the Cleaned dataset file
df.to_csv('Algerian forest CLEANED dataset.csv',index=False)

# %% [markdown]
# # Exploratory data Analysis

# %%
## DRop the day,month ,year

df_copy = df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire       0

# %%
# Categories if the Classes i.etarget features
df_copy['Classes'].value_counts()
# Out:
# fire        137
# not fire    105
# Name: Classes, dtype: int64

# %%
# Encoding of the Categories in classes
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 237           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 238           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 239           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 240           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 241           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 237       1
# 238       1
# 239       1
# 240       1
# 241       1

# %%
df_copy['Classes'].value_counts()
# Out:
# 1    137
# 0    105
# Name: Classes, dtype: int64

# %% [markdown]
# # Observation
# #### It is an type of Imbalanced dataset beacuse here the 1 values is greater than the 0's value

# %% [markdown]
# # Data Visulization

# %%
# Plot densoty plot for all fetures
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,20))
plt.show()
# Out:
# C:\Users\AKASH VISHWAKARMA\AppData\Local\Temp\ipykernel_17456\875327391.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Percentage for pie chart
percentange = df_copy['Classes'].value_counts(normalize=True)*100

# %%
#plotting Pie chart
classlabels = ['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pie(percentange,labels=classlabels,autopct='%1.1f%%')
plt.title("PIE CHART OF CLASSES")
plt.show()

# %%
sns.heatmap(df_copy.corr(),annot=True,linewidth=.15)
# Out:
# <Axes: >

# %%
## MOnthly Fire analysis
dftemp = df.loc[df['Region']==0]
plt.subplots(figsize=(13,13))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.xlabel("Months")
plt.title("Fire Analysis of Brjais Region")
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Brjais Region')

# %% [markdown]
# # Model Training

# %%
## Independent And dependent features
X=df_copy.drop('FWI',axis=1)
y=df_copy['FWI']

# %%
X.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 237    6.5
# 238    0.0
# 239    0.2
# 240    0.7
# 241    0.5
# Name: FWI, Length: 242, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((181, 11), (61, 11))

# %%
## Feature Selection based on correlaltion
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.650346 -0.302105 -0.329711  0.703237  0.494261
# RH             -0.650346  1.000000  0.266525  0.234932 -0.634330 -0.413931
# Ws             -0.302105  0.266525  1.000000  0.219681 -0.171843  0.000277
# Rain           -0.329711  0.234932  0.219681  1.000000 -0.546501 -0.286855
# FFMC            0.703237 -0.634330 -0.171843 -0.546501  1.000000  0.621240
# DMC             0.494261 -0.413931  0.000277 -0.286855  0.621240  1.000000
# DC              0.377424 -0.246125  0.105115 -0.300276  0.537884  0.876734
# ISI             0.617606 -0.693939  0.005360 -0.346706  0.751558  0.693404
# BUI             0.466352 -0.364136  0.038701 -0.297934  0.610780  0.983698
# Classes         0.525551 -0.435094 -0.059470 -0.386323  0.780805  0.613507
# Region          0.249598 -0.364007 -0.235477 -0.065132  0.222702  0.196778
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %% [markdown]
# # Feature Selection

# %%
# CHeck the Multicollinearity 
# Multicollinearlty is the Concept in which the one or more independent are having same percentage to predict the target varible , Hence here we remove the one feature from both of them......
# And the percentage of the feature is decided by the Domain Expertise in that domain

plt.figure(figsize=(12,12))
corr= X_train.corr()
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
X_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.650346 -0.302105 -0.329711  0.703237  0.494261
# RH             -0.650346  1.000000  0.266525  0.234932 -0.634330 -0.413931
# Ws             -0.302105  0.266525  1.000000  0.219681 -0.171843  0.000277
# Rain           -0.329711  0.234932  0.219681  1.000000 -0.546501 -0.286855
# FFMC            0.703237 -0.634330 -0.171843 -0.546501  1.000000  0.621240
# DMC             0.494261 -0.413931  0.000277 -0.286855  0.621240  1.000000
# DC              0.377424 -0.246125  0.105115 -0.300276  0.537884  0.876734
# ISI             0.617606 -0.693939  0.005360 -0.346706  0.751558  0.693404
# BUI             0.466352 -0.364136  0.038701 -0.297934  0.610780  0.983698
# Classes         0.525551 -0.435094 -0.059470 -0.386323  0.780805  0.613507
# Region          0.249598 -0.364007 -0.235477 -0.065132  0.222702  0.196778
#
#                    DC       ISI       BUI   Classes    Region
# ...

# %%
def correlation(dataset,threshold):
    col_corr = set()
    corr_matrix = df_copy.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if(abs(corr_matrix.iloc[i,j]) ) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train,0.90)

# %%
corr_features
# Out:
# {'BUI', 'FWI'}

# %%
# # Drop the features having correlation greater than 0.85
# X_train.drop(corr_features,axis=1,inplace=True)
# X_test.drop(corr_features,axis=1,inplace=True)
# X_train.shape,X_test.shape
# Step 1: Print corr_features to check its content
print("Columns to drop:", corr_features)

# Step 2: Verify column names in X_train and X_test
print("Columns in X_train:", X_train.columns.tolist())
print("Columns in X_test:", X_test.columns.tolist())

# Check which columns in corr_features are not in X_train
missing_in_X_train = [col for col in corr_features if col not in X_train.columns]
missing_in_X_test = [col for col in corr_features if col not in X_test.columns]

# Step 3: Print missing columns to identify the issue
if missing_in_X_train:
    print("Columns in corr_features but not in X_train:", missing_in_X_train)
if missing_in_X_test:
    print("Columns in corr_features but not in X_test:", missing_in_X_test)

# Proceed to drop the columns only if they exist in both DataFrames
common_columns_to_drop = [col for col in corr_features if col in X_train.columns and col in X_test.columns]
print("Common columns to drop:", common_columns_to_drop)

# Drop the features from both training and test sets
X_train.drop(common_columns_to_drop, axis=1, inplace=True)
X_test.drop(common_columns_to_drop, axis=1, inplace=True)

# Verify the shapes of the DataFrames after dropping the columns
print(X_train.shape, X_test.shape)
# Out:
# Columns to drop: {'BUI', 'FWI'}
# Columns in X_train: ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'Region']
# Columns in X_test: ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'Region']
# Columns in corr_features but not in X_train: ['FWI']
# Columns in corr_features but not in X_test: ['FWI']
# Common columns to drop: ['BUI']
# (181, 10) (61, 10)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %% [markdown]
# # Feature Scaling and Standardization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.82836812,  0.75305576,  1.27406033, ..., -0.60658617,
#         -1.07459849, -0.98356052],
#        [-0.02800533, -0.52331623, -0.52192814, ...,  0.08124507,
#          0.93058013,  1.01671425],
#        [-0.82836812, -1.46380085, -2.67711431, ..., -0.46427625,
#          0.93058013,  1.01671425],
#        ...,
#        [-1.89551851,  0.88741071,  0.55566494, ..., -1.05723422,
#         -1.07459849, -0.98356052],
#        [ 1.03914506, -0.45613875,  0.19646725, ...,  0.84023126,
#          0.93058013,  1.01671425],
#        [-0.56158052,  0.95458818,  1.99245572, ..., -0.84376935,
#         -1.07459849, -0.98356052]])

# %%
# X_test_scaled

# %% [markdown]
# # Box Plot to understand the effect of Standard Scaler

# %%
plt.subplots(figsize=(15,5))
plt.subplot(1,2,1)
sns.boxplot(data=X_train)
plt.title("X_train Before Scaling")
plt.subplot(1,2,2)
sns.boxplot(data=X_train_scaled)
plt.title("X_train After Scaling")
# Out:
# C:\Users\AKASH VISHWAKARMA\AppData\Local\Temp\ipykernel_17456\617705874.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)
# Text(0.5, 1.0, 'X_train After Scaling')

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg = LinearRegression()
linreg.fit(X_train_scaled,y_train)
y_pred = linreg.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error is : ",mae)
print("Accuracy of the Model is ==>>",score)
# Out:
# Mean Absolute Error is :  0.5897274730814096
# Accuracy of the Model is ==>> 0.9798407754773322

# %% [markdown]
# # lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso = Lasso()
lasso.fit(X_train_scaled,y_train)
y_pred = lasso.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error is : ",mae)
print("Accuracy of the Model is ==>>",score)
# Out:
# Mean Absolute Error is :  1.149422993029409
# Accuracy of the Model is ==>> 0.9496355704152465

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge = Ridge()
ridge.fit(X_train_scaled,y_train)
y_pred = ridge.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error is : ",mae)
print("Accuracy of the Model is ==>>",score)
# Out:
# Mean Absolute Error is :  0.6177281181384903
# Accuracy of the Model is ==>> 0.9783910690698754

# %% [markdown]
# # Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic = ElasticNet()
elastic.fit(X_train_scaled,y_train)
y_pred = elastic.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
score = r2_score(y_test,y_pred)
print("Mean Absolute Error is : ",mae)
print("Accuracy of the Model is ==>>",score)
# Out:
# Mean Absolute Error is :  1.8393137177692631
# Accuracy of the Model is ==>> 0.873045032987447

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(linreg,open('regressor.pkl','wb'))
